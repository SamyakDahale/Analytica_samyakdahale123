# %%
import random # STEP 3 
import re
from nltk.tokenize import sent_tokenize, word_tokenize
import spacy

# Load the spaCy model for named entity recognition
nlp = spacy.load("en_core_web_sm")

def truncate_sentence(sentence, max_words=10):
    """Limit sentence length to a maximum number of words."""
    words = word_tokenize(sentence)
    if len(words) > max_words:
        return ' '.join(words[:max_words]) + '...'
    return sentence

def generate_diverse_questions(sentences, num_questions=5, max_words=10):
    """Generate exactly 10 diverse and meaningful questions from a list of sentences."""
    questions = set()  # Use a set to avoid duplicate questions

    while len(questions) < num_questions:
        for sentence in sentences:
            if len(questions) >= num_questions:
                break

            # Analyze the sentence with spaCy to extract entities
            doc = nlp(sentence)
            entities = [(ent.text, ent.label_) for ent in doc.ents]

            # 1. General Questions
            general_starter = random.choice([
                "What is the meaning of",
                "Why is it important to understand",
                "How does",
                "What is the role of",
                "Explain the significance of"
            ])
            truncated_sentence = truncate_sentence(sentence, max_words=max_words)
            questions.add(f"{general_starter} {truncated_sentence.strip()}?")

            # 2. Entity-based Questions
            for entity, label in entities:
                questions.add(f"What role does '{entity}' play in {truncated_sentence.strip()}?")
                if label in ["PERSON", "ORG", "GPE"]:  # Person, Organization, or Geopolitical entity
                    questions.add(f"How does '{entity}' influence the events in {truncated_sentence.strip()}?")
                    questions.add(f"What is the significance of '{entity}' in the context of {truncated_sentence.strip()}?")

            # 3. Why and How Questions (focusing on reasons or methods)
            questions.add(f"Why is {truncated_sentence.strip()} important?")
            questions.add(f"How can {truncated_sentence.strip()} be applied in real life?")

            # 4. Hypothetical or Exploratory Questions
            questions.add(f"What would happen if {truncated_sentence.strip()} didn't occur?")
            questions.add(f"What are the potential consequences of {truncated_sentence.strip()}?")

    return list(questions)

def generate_questions_from_text(tokenized_text, num_questions=10, max_words=20):
    """Generate 10 meaningful and different questions from the tokenized text of the book."""
    sentences = sent_tokenize(tokenized_text)
    generated_questions = generate_diverse_questions(sentences, num_questions=num_questions, max_words=max_words)
    return generated_questions

# Example usage for identifying the book and generating questions
prompt = input("Please enter your prompt: ")  # Ask the user to input a prompt
book_title, similarity_score = identify_book(prompt)
print(f"Most Relevant Book: {book_title}, Similarity Score: {similarity_score:.4f}")

# Check if the book exists in the DataFrame and retrieve the tokenized text
if book_title in books_df['Title'].values:
    tokenized_text = books_df.loc[books_df['Title'] == book_title, 'Tokenized Text'].values
    if len(tokenized_text) > 0:
        tokenized_text = tokenized_text[0]  # Access the text

        # Generate 10 meaningful and different questions from the tokenized text
        generated_questions = generate_questions_from_text(tokenized_text, num_questions=5, max_words=10)
        
        # Print the generated questions
        print("\nGenerated Questions:")
        for i, question in enumerate(generated_questions, 1):
            print(f"Q{i}: {question}")
    else:
        print(f"No tokenized text found for the book '{book_title}'.")
else:
    print(f"Book title '{book_title}' not found in the dataset.")
# Out:
# Most Relevant Book: GandhiAutobio_morallessons, Similarity Score: 0.4629
#
# Generated Questions:
# Q1: How does 'mahatma' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q2: What is the significance of 'absence gandhi' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q3: What role does 'new delhi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q4: What role does 'lesson gandhi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q5: What role does 'gymnastic' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q6: What would happen if gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti... didn't occur?
# Q7: What is the significance of 'listens gandhi' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q8: How does 'mahatma gandhi' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q9: What role does 'four afternoon' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q10: What is the significance of 'gandhi exception' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q11: What role does 'one day' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q12: What are the potential consequences of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q13: What role does 'gandhi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q14: What role does 'year' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q15: What role does 'gandhi autobiography gandhi smriti' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q16: What role does 'jaw sin' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q17: What is the significance of 'godse shot gandhi' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q18: What role does 'chapter ii' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q19: What role does 'january' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q20: What role does 'gandhi critical hour' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q21: What is the significance of 'mahatma' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q22: What role does 'chapter xii' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q23: How does 'london' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q24: What role does 'india' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q25: What role does 'european' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q26: How does 'shravana pitrubhakti natak' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q27: How does 'gandhi autobiography gandhi smriti' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q28: What is the significance of 'india' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q29: What is the significance of 'gandhi autobiography gandhi smriti' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q30: What role does 'mahatma' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q31: What is the significance of 'gandhi marg' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q32: How does 'dharma chakra' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q33: What role does 'indian' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q34: What is the significance of 'pp national flag truth' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q35: What is the significance of 'mahatma saint' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q36: How does 'absence gandhi' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q37: What is the significance of 'shravana pitrubhakti natak' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q38: What role does 'today' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q39: What is the significance of 'jaw sin' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q40: What role does 'mahatma saint' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q41: What is the significance of 'new delhi' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q42: What role does 'every night' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q43: What role does 'admirer gandhi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q44: How does 'mahatma saint' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q45: What role does 'saturday' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q46: How does 'gandhi brothel' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q47: What role does 'gandhi exception' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q48: How does 'sri vasudevan' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q49: How does 'jaw sin' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q50: What is the significance of 'hindi sanskrit' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q51: How does 'new delhi' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q52: What role does 'shravana pitrubhakti natak' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q53: How does 'india' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q54: What role does 'gandhi brothel' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q55: What is the significance of 'gandhi smriti' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q56: What role does 'india indian' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q57: What role does 'century' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q58: What role does 'first quarter century' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q59: What role does 'mahatma gandhi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q60: How does 'godse shot gandhi' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q61: What role does 'dharma chakra' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q62: How does 'martin luther king' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q63: How does 'listens gandhi' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q64: What role does 'sri vasudevan' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q65: How does 'pp national flag truth' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q66: What role does 'chapter v high school' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q67: What role does 'arabic english' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q68: What role does 'fiftieth' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q69: How does 'admirer gandhi' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q70: How can gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti... be applied in real life?
# Q71: What role does 'fifty year' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q72: What role does 'english' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q73: What role does 'french' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q74: What role does 'three' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q75: How does 'gandhi critical hour' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q76: How does gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q77: How does 'gandhi smriti' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q78: What role does 'night' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q79: What role does 'first' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q80: What role does 'thirty year' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q81: What is the significance of 'lesson gandhi' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q82: What role does 'persian' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q83: How does 'jesus buddha prophet mohammad' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q84: What is the significance of 'mahatma gandhi' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q85: What role does 'chapter xi preparation england' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q86: What role does 'listens gandhi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q87: What role does 'democratic' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q88: What is the significance of 'london' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q89: What role does 'chapter xvi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q90: What role does 'free india satyameva jayate truth alone triumph thus' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q91: What role does 'daily' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q92: What role does 'godse shot gandhi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q93: What role does 'martin luther king' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q94: What role does 'next day' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q95: What is the significance of 'gandhi' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q96: What role does 'pp national flag truth' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q97: What is the significance of 'dharma chakra' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q98: What role does 'chapter xv' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q99: What role does 'one' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q100: What is the significance of 'sri vasudevan' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q101: What is the significance of 'martin luther king' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q102: How does 'gandhi exception' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q103: How does 'gandhi marg' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q104: What role does 'chapter xiv' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q105: What role does 'gandhi marg' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q106: What role does 'jeernani vasamsi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q107: What role does 'london' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q108: What role does 'december' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q109: How does 'hindi sanskrit' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q110: What role does 'gandhi smriti' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q111: What is the significance of 'jeernani vasamsi' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q112: Why is gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti... important?
# Q113: What is the significance of 'free india satyameva jayate truth alone triumph thus' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q114: How does 'lesson gandhi' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q115: What role does 'hindi sanskrit' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q116: What is the significance of 'gandhi critical hour' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q117: What role does 'four' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q118: What is the significance of 'admirer gandhi' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q119: What is the significance of 'jesus buddha prophet mohammad' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q120: What role does 'absence gandhi' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q121: How does 'gandhi' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q122: How does 'jeernani vasamsi' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q123: What role does 'latin' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q124: What role does 'ten' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q125: What role does 'jesus buddha prophet mohammad' play in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q126: What is the significance of 'gandhi brothel' in the context of gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
# Q127: How does 'free india satyameva jayate truth alone triumph thus' influence the events in gandhi autobiography moral lesson gangrade published gandhi smriti darshan samiti...?
